# %% [markdown]
# Bắt đầu

# %% [markdown]
# ex2_scientific1

# %% [markdown]
# Nội dung bài:
#
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$

# %% [markdown]
# Bài làm

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# Sinh ngẫu nhiên hình tròn

# %%
# %time
# generate randomly the center (x,y ) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2  # 0 to 15 point radii
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %% [markdown]
# Mã kiểm tra dữ liệu

# %%
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area[0:10]}]')
# Out:
# + x: len=50, [0.01, 0.95]: 10 samples [[0.56458677 0.17899346 0.90214347 0.05816008 0.12063737 0.69626885
#  0.14197167 0.95465605 0.10495312 0.91698972]]
# + y: len=50, [0.00, 0.97]: 10 samples [[0.52824914 0.77031502 0.88739267 0.61897225 0.07761395 0.29153186
#  0.88541054 0.00213514 0.89048423 0.83743624]]
# + colors: len=50, [0.00, 1.00]: 10 samples [[0.88764121 0.003943   0.33265634 0.04901286 0.33094856 0.73745984
#  0.33640922 0.11322384 0.38553499 0.48472835]]
# + area: len=50, [0.02, 697.94]: 10 samples [[212.29062592 270.37490154 162.53067415 564.18326366 110.7560713
#  473.15414055   1.91931265  26.43799481  49.76814432  18.2181843 ]]

# %% [markdown]
# Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# Kết thúc
